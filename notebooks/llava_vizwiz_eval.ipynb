# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Clone LLaVA-VQA and install dependencies

# %%
# %cd /content
# !git clone --recursive https://github.com/PatrickKollman/LLaVA-VQA.git
# Out:
# /content
# Cloning into 'LLaVA-VQA'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 247 (delta 127), reused 174 (delta 59), pack-reused 0
# Receiving objects: 100% (247/247), 2.12 MiB | 42.48 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# Submodule 'LLaVA' (https://github.com/haotian-liu/LLaVA.git) registered for path 'LLaVA'
# Submodule 'VQA' (https://github.com/GT-Vision-Lab/VQA.git) registered for path 'VQA'
# Cloning into '/content/LLaVA-VQA/LLaVA'...
# remote: Enumerating objects: 2297, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 2297 (delta 2), reused 4 (delta 2), pack-reused 2291
# Receiving objects: 100% (2297/2297), 13.72 MiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (1403/1403), done.
# Cloning into '/content/LLaVA-VQA/VQA'...
# remote: Enumerating objects: 296, done.
# ...

# %%
# %cd /content/LLaVA-VQA
# !pip install -e .  # Install my repo dependencies
# Out:
# /content/LLaVA-VQA
# Obtaining file:///content/LLaVA-VQA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd /content/LLaVA-VQA/LLaVA
# !pip install -e . --no-deps  # Install LLaVA code
# Out:
# /content/LLaVA-VQA/LLaVA
# Obtaining file:///content/LLaVA-VQA/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.2.2.post1-0.editable-py3-none-any.whl size=17866 sha256=91361ec780ae39c8a683dd3b26ffd63b40c855d93809767aa05be8758173e145
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uh7s67dn/wheels/15/53/71/579f84e22486e2f4bdd69bf759c3cba3b736859932b52bcdbe
# Successfully built llava
# ...

# %%
# !pip uninstall jax -y  # Google Colab JAX competes with DataLoader multiprocessing
# Out:
# Found existing installation: jax 0.4.26
# Uninstalling jax-0.4.26:
#   Successfully uninstalled jax-0.4.26

# %% [markdown]
# ### Copy data from Google Drive and unzip

# %%
# !cp /content/drive/MyDrive/VizWiz/data/Images/test.zip /content

# %%
# !cp /content/drive/MyDrive/VizWiz/data/Annotations/original_format/test.json /content

# %%
# %cd /content
# !unzip test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/VizWiz_test_00003342.jpg
#   inflating: test/VizWiz_test_00006376.jpg
#   inflating: test/VizWiz_test_00004289.jpg
#   inflating: test/VizWiz_test_00006040.jpg
#   inflating: test/VizWiz_test_00001386.jpg
#   inflating: test/VizWiz_test_00007685.jpg
#   inflating: test/VizWiz_test_00004583.jpg
#   inflating: test/VizWiz_test_00001222.jpg
#   inflating: test/VizWiz_test_00003630.jpg
#   inflating: test/VizWiz_test_00003286.jpg
#   inflating: test/VizWiz_test_00000929.jpg
#   inflating: test/VizWiz_test_00007865.jpg
#   inflating: test/VizWiz_test_00004519.jpg
#   inflating: test/VizWiz_test_00001309.jpg
#   inflating: test/VizWiz_test_00005345.jpg
#   inflating: test/VizWiz_test_00003647.jpg
#   inflating: test/VizWiz_test_00001845.jpg
#   inflating: test/VizWiz_test_00006197.jpg
#   inflating: test/VizWiz_test_00004227.jpg
#   inflating: test/VizWiz_test_00002907.jpg
#   inflating: test/VizWiz_test_00004703.jpg
# ...

# %%
# !rm test.zip

# %% [markdown]
# # Evaluate LLaVA on VizWiz

# %%
# %cd /content/LLaVA-VQA/src/eval/vizwiz
# !chmod +x eval_local_vizwiz.sh
# !./eval_local_vizwiz.sh
# Out:
# /content/LLaVA-VQA/src/eval/vizwiz
# 2024-07-19 21:56:57.510373: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-19 21:56:57.560279: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-19 21:56:57.560325: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-19 21:56:57.561852: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp /content/answers/checkpoint-100-llava-v1.5-7b.json /content/drive/MyDrive/VizWiz/data/Answers/
