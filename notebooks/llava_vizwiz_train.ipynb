# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Clone LLaVA-VQA and install dependencies

# %%
# %cd /content
# !git clone --recursive https://github.com/PatrickKollman/LLaVA-VQA.git
# Out:
# /content
# Cloning into 'LLaVA-VQA'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 247 (delta 127), reused 174 (delta 59), pack-reused 0
# Receiving objects: 100% (247/247), 2.12 MiB | 32.33 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# Submodule 'LLaVA' (https://github.com/haotian-liu/LLaVA.git) registered for path 'LLaVA'
# Submodule 'VQA' (https://github.com/GT-Vision-Lab/VQA.git) registered for path 'VQA'
# Cloning into '/content/LLaVA-VQA/LLaVA'...
# remote: Enumerating objects: 2297, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 2297 (delta 2), reused 4 (delta 2), pack-reused 2291
# Receiving objects: 100% (2297/2297), 13.71 MiB | 10.79 MiB/s, done.
# Resolving deltas: 100% (1402/1402), done.
# Cloning into '/content/LLaVA-VQA/VQA'...
# remote: Enumerating objects: 296, done.
# ...

# %%
# %cd /content/LLaVA-VQA
# !pip install -e .  # Install my repo dependencies
# Out:
# /content/LLaVA-VQA
# Obtaining file:///content/LLaVA-VQA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd /content/LLaVA-VQA/LLaVA
# !pip install -e . --no-deps  # Install local LLaVA code
# Out:
# /content/LLaVA-VQA/LLaVA
# Obtaining file:///content/LLaVA-VQA/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.2.2.post1-0.editable-py3-none-any.whl size=17865 sha256=f8073ddd6ba441156263b939c9a35dc96e121b3bf4f80335c197fd2eab9a4bca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6b1rkcgo/wheels/15/53/71/579f84e22486e2f4bdd69bf759c3cba3b736859932b52bcdbe
# Successfully built llava
# ...

# %%
# !pip uninstall jax -y  # Google Colab JAX competes with DataLoader multiprocessing
# Out:
# Found existing installation: jax 0.4.26
# Uninstalling jax-0.4.26:
#   Successfully uninstalled jax-0.4.26

# %%
# !MAX_JOBS=4 pip install flash-attn --no-build-isolation  # Flash Attention for Training
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 22.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for flash-attn: filename=flash_attn-2.6.1-cp310-cp310-linux_x86_64.whl size=198447665 sha256=808523ff263d2fc1d3801147ad90d89dbfca67623a110c26592aef2064ea7b65
#   Stored in directory: /root/.cache/pip/wheels/91/6a/38/f0faa036b4ac73a73247386f1ab1bb4cb4f6e72e6861a779f1
# Successfully built flash-attn
# ...

# %% [markdown]
# ### Copy Annotations

# %%
# !cp /content/drive/MyDrive/VizWiz/data/Annotations/llava_format/train.json /content

# %% [markdown]
# ### Copy and unzip images

# %%
# !cp /content/drive/MyDrive/VizWiz/data/Images/train.zip /content

# %%
# %cd /content
# !unzip train.zip
# !rm train.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/VizWiz_train_00016897.jpg
#   inflating: train/VizWiz_train_00022049.jpg
#   inflating: train/VizWiz_train_00010269.jpg
#   inflating: train/VizWiz_train_00001449.jpg
#   inflating: train/VizWiz_train_00004288.jpg
#   inflating: train/VizWiz_train_00011536.jpg
#   inflating: train/VizWiz_train_00003138.jpg
#   inflating: train/VizWiz_train_00000748.jpg
#   inflating: train/VizWiz_train_00007422.jpg
#   inflating: train/VizWiz_train_00014674.jpg
#   inflating: train/VizWiz_train_00004900.jpg
#   inflating: train/VizWiz_train_00022766.jpg
#   inflating: train/VizWiz_train_00010259.jpg
#   inflating: train/VizWiz_train_00005425.jpg
#   inflating: train/VizWiz_train_00011918.jpg
#   inflating: train/VizWiz_train_00008013.jpg
#   inflating: train/VizWiz_train_00009540.jpg
#   inflating: train/VizWiz_train_00013833.jpg
#   inflating: train/VizWiz_train_00023196.jpg
#   inflating: train/VizWiz_train_00000160.jpg
# ...

# %% [markdown]
# # Train LLaVA on VizWiz

# %%
# %cd /content/LLaVA-VQA/src/train
# !chmod +x finetune_vizwiz_lora.sh
# !./finetune_vizwiz_lora.sh

# %%
# %cd /content/LLaVA-VQA/
# !git diff

# %%
while T
