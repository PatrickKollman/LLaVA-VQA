# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Clone LLaVA-VQA and install dependencies

# %%
# %cd /content
# !git clone --recursive https://github.com/PatrickKollman/LLaVA-VQA.git
# Out:
# /content
# Cloning into 'LLaVA-VQA'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 91 (delta 46), reused 65 (delta 22), pack-reused 0
# Receiving objects: 100% (91/91), 1.55 MiB | 4.14 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Submodule 'LLaVA' (https://github.com/haotian-liu/LLaVA.git) registered for path 'LLaVA'
# Submodule 'VQA' (https://github.com/GT-Vision-Lab/VQA.git) registered for path 'VQA'
# Cloning into '/content/LLaVA-VQA/LLaVA'...
# remote: Enumerating objects: 2297, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 2297 (delta 2), reused 4 (delta 2), pack-reused 2291
# Receiving objects: 100% (2297/2297), 13.72 MiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (1403/1403), done.
# Cloning into '/content/LLaVA-VQA/VQA'...
# remote: Enumerating objects: 296, done.
# ...

# %%
# %cd /content/LLaVA-VQA
# !pip install -e .  # Install my repo dependencies
# Out:
# /content/LLaVA-VQA
# Obtaining file:///content/LLaVA-VQA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 97.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.2/318.2 kB 43.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# %cd /content/LLaVA-VQA/LLaVA
# !pip install -e . --no-deps  # Install LLaVA code
# Out:
# /content/LLaVA-VQA/LLaVA
# Obtaining file:///content/LLaVA-VQA/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.2.2.post1-0.editable-py3-none-any.whl size=17855 sha256=486e02da1dbf58537ac332ef0b2a10f7dabe21e14376f742e289df8958bcdfb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5ghxvf32/wheels/15/53/71/579f84e22486e2f4bdd69bf759c3cba3b736859932b52bcdbe
# Successfully built llava
# ...

# %%
# !pip uninstall jax -y  # JAX competes with DataLoader multiprocessing
# Out:
# Found existing installation: jax 0.4.26
# Uninstalling jax-0.4.26:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/jax-0.4.26.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/jax/*
# Proceed (Y/n)?   ERROR: Operation cancelled by user

# %% [markdown]
# ### Copy data from Google Drive and unzip

# %%
# !cp /content/drive/MyDrive/VQA/data/Questions/v2_OpenEnded_mscoco_test-dev2015_questions.json /content

# %%
# !cp /content/drive/MyDrive/VQA/data/Images/test2015.zip /content

# %%
# %cd /content
# !unzip test2015.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: test2015/COCO_test2015_000000303195.jpg
#  extracting: test2015/COCO_test2015_000000481207.jpg
#  extracting: test2015/COCO_test2015_000000229167.jpg
#  extracting: test2015/COCO_test2015_000000466120.jpg
#  extracting: test2015/COCO_test2015_000000237368.jpg
#  extracting: test2015/COCO_test2015_000000009689.jpg
#  extracting: test2015/COCO_test2015_000000064513.jpg
#  extracting: test2015/COCO_test2015_000000058293.jpg
#  extracting: test2015/COCO_test2015_000000449819.jpg
#  extracting: test2015/COCO_test2015_000000106852.jpg
#  extracting: test2015/COCO_test2015_000000227623.jpg
#  extracting: test2015/COCO_test2015_000000250613.jpg
#  extracting: test2015/COCO_test2015_000000347395.jpg
#  extracting: test2015/COCO_test2015_000000388934.jpg
#  extracting: test2015/COCO_test2015_000000047455.jpg
#  extracting: test2015/COCO_test2015_000000523288.jpg
#  extracting: test2015/COCO_test2015_000000368687.jpg
# ...

# %%
# !rm test2015.zip

# %% [markdown]
# ### Test LLaVA on VQA

# %%
# %cd /content/LLaVA-VQA/src/eval
# !chmod +x eval_vqa_v2.sh
# !./eval_vqa_v2.sh
# Out:
# /content/LLaVA-VQA/src/eval
# 2024-06-30 05:20:47.224216: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-30 05:20:48.049224: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-30 05:20:48.049302: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-30 05:20:48.163267: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
